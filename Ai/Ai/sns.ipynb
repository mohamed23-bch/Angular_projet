# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("Orders.csv")

data.head()
# Out:
#    Order ID  Order Date  Day               Country        City      Lat  \
# 0         1  01/01/2023  Mon                 Syria        homs  34.7326
# 1         2  01/01/2023  Tue          Saudi Arabia      riyadh  24.7136
# 2         3  01/01/2023  Tue          Saudi Arabia      riyadh  24.7743
# 3         4  01/01/2023  Mon  United Arab Emirates   abu dhabi  24.4539
# 4         5  01/01/2023  Wed                   USA  washington  38.9072
#
#        Lng       Full Name        Category        Sub Category  \
# 0  36.7136  Lina Alrrashid          Tablet          Apple iPad
# 1  46.6753      Omar Eurul      Smartphone      Samsung Galaxy
# 2  46.7386   Iman Iismaeil  Digital Camera     Panasonic Lumix
# 3  54.3773     Ahmad Rihan          Tablet  Samsung Galaxy Tab
# 4 -77.0369    Sami Altawil      Headphones       Sennheiser HD
#
#                   Item SalesPerson ID  Quantity  Unit Price  Discount  \
# 0       iPad Pro 12.9"           N498         4         999   38.3616
# ...

# %%
sns.histplot(data['Quantity'],bins = 5)
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
sns.barplot(x='Category', y='Unit Price',data=data,palette='crest')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_9164\3913807908.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Category', y='Unit Price',data=data,palette='crest')
# <Axes: xlabel='Category', ylabel='Unit Price'>

# %%
# data.info()
data.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 # data.info()
# ----> 2 data.corr()
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %%
sns.scatterplot(x='Discount',y='Total Cost' ,data=data ,size='Quantity')
# Out:
# <Axes: xlabel='Discount', ylabel='Total Cost'>

# %%
sns.boxplot(x='Day',y='Quantity',data=data)
# Out:
# <Axes: xlabel='Day', ylabel='Quantity'>
